# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "Qwen/Qwen3-0.6B"
save_directory = "./models/qwen3-0.6b-base"

print("Downloading model (progress will show automatically)...")
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print("Saving model...")
tokenizer.save_pretrained(save_directory)
model.save_pretrained(save_directory)

print("Done!")
# Out:
# Downloading model (progress will show automatically)...
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Saving model...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Done!

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Load directly from your local folder
tokenizer = AutoTokenizer.from_pretrained(save_directory)
model = AutoModelForCausalLM.from_pretrained(
    save_directory,
    device_map="auto",
    torch_dtype=torch.float16
)

print("Model successfully loaded from local storage!")
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]
# Model successfully loaded from local storage!

# %%
# Define your prompt message
messages = [
    {"role": "user", "content": "Explain the concept of quantum computing in simple terms"}
]

# Apply the model's specific chat format
formatted_prompt = tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True
)

# Tokenize, move to device, and generate
inputs = tokenizer(formatted_prompt, return_tensors="pt").to(model.device)

# Adjust generation parameters for better creativity and flow
outputs = model.generate(
    **inputs, 
    max_new_tokens=200,
    temperature=0.7,      # Controls randomness (higher = more creative)
    do_sample=True        # Required when using temperature
)

# Decode only the newly generated tokens
input_length = inputs.input_ids.shape[1]
response = tokenizer.decode(outputs[0][input_length:], skip_special_tokens=True)

print(response)
# Out:
# <think>
# Okay, the user wants to explain quantum computing in simple terms. Let me start by recalling what I know. Quantum computing uses quantum bits, or qubits, which are different from classical bits. Classical bits are either 0 or 1, but qubits can be both, right? So that's the key difference.
#
# I should compare it to regular computers. Regular computers use bits, and quantum computers use qubits. But how does that work? Maybe explain that qubits can be in a superposition state. Like, a qubit can be both 0 and 1 at the same time until measured. That's a superposition.
#
# Then there's entanglement. When qubits are entangled, the state of one qubit is connected to another. So if you measure one, the other instantly knows, and vice versa. This could allow quantum computers to perform calculations faster than classical computers.
#
# But wait, how do you handle the measurement? Maybe mention that after a

# %%
messages = [
    {"role": "user", "content": "Explain the concept of quantum computing in simple terms"}
]

formatted_prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(formatted_prompt, return_tensors="pt").to(model.device)
# Out:
# <think>
# Okay, so I need to explain quantum computing in simple terms. Let me start by recalling what I know. Quantum computing uses quantum bits, or qubits, right? Unlike regular bits that are either 0 or 1, qubits can be in a superposition of both states at the same time. That's something I remember from physics, like the double-slit experiment. But how does that apply here?
#
# Wait, so the idea is that qubits can exist in multiple states at once. So instead of just 0 or 1, they can be a combination. But then there's entanglement. When qubits are entangled, they have a correlation between their states. So if one qubit is 0, the other is also 0, and if one is 1, the other is 1. But this might be a bit confusing. Maybe I should use an analogy.
#
# Imagine you have two coins. One can be heads or tails, and

# %%
outputs = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

input_length = inputs.input_ids.shape[1]
response = tokenizer.decode(
    outputs[0][input_length:],
    skip_special_tokens=True
)

print(response)
